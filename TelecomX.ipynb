# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd

# %%
dato_telecom = pd.read_json('TelecomX_Data.json')

# %%
datos_telecom
# Out:
#        customerID Churn                                           customer  \
# 0      0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1      0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2      0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3      0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4      0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...           ...   ...                                                ...
# 10920  9524-EGPJC   Yes  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 10922  9526-BIHHD   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 10923  9526-JAWYF   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 10925  9529-OFXHY    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 10926  9530-EHPOH   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                    phone  \
# ...

# %%
df_customer = pd.json_normalize(datos_telecom['customer'])
df_customer
# Out:
#        gender  SeniorCitizen Partner Dependents  tenure
# 0      Female              0     Yes        Yes       9
# 1        Male              0      No         No       9
# 2        Male              0      No         No       4
# 3        Male              1     Yes         No      13
# 4      Female              1     Yes         No       3
# ...       ...            ...     ...        ...     ...
# 10590  Female              0      No         No      18
# 10591    Male              0      No         No       1
# 10592    Male              0      No         No      26
# 10593    Male              0      No         No      15
# 10594    Male              0      No         No      11
#
# [10595 rows x 5 columns]

# %%
df_norm = pd.json_normalize(datos_telecom['account'])
df_norm
# Out:
#              Contract PaperlessBilling              PaymentMethod  \
# 0            One year              Yes               Mailed check
# 1      Month-to-month               No               Mailed check
# 2      Month-to-month              Yes           Electronic check
# 3      Month-to-month              Yes           Electronic check
# 4      Month-to-month              Yes               Mailed check
# ...               ...              ...                        ...
# 10590  Month-to-month              Yes           Electronic check
# 10591  Month-to-month               No               Mailed check
# 10592  Month-to-month               No           Electronic check
# 10593  Month-to-month              Yes  Bank transfer (automatic)
# 10594  Month-to-month               No           Electronic check
#
#        Charges.Monthly Charges.Total
# 0                65.60         593.3
# 1                59.90         542.4
# 2                73.90        280.85
# ...

# %%
datos_telecom = pd.concat([dato_telecom, df_norm, df_customer], axis=1)
datos_telecom
# Out:
#        customerID Churn                                           customer  \
# 0      0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1      0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2      0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3      0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4      0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...           ...   ...                                                ...
# 11270  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 11271  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 11272  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 11273  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 11274  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                    phone  \
# ...

# %%
type(df_norm)
# Out:
# pandas.core.frame.DataFrame

# %%
datos_telecom.dtypes
# Out:
# customerID           object
# Churn                object
# customer             object
# phone                object
# internet             object
# account              object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# Charges.Monthly     float64
# Charges.Total        object
# gender               object
# SeniorCitizen       float64
# Partner              object
# Dependents           object
# tenure              float64
# dtype: object

# %% [markdown]
# #🔧 Transformación

# %%
datos_telecom.dtypes
# Out:
# customerID           object
# Churn                object
# customer             object
# phone                object
# internet             object
# account              object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# Charges.Monthly     float64
# Charges.Total        object
# gender               object
# SeniorCitizen       float64
# Partner              object
# Dependents           object
# tenure              float64
# dtype: object

# %%
datos_telecom.isnull()
# Out:
#        customerID  Churn  customer  phone  internet  account  Contract  \
# 0           False  False     False  False     False    False     False
# 1           False  False     False  False     False    False     False
# 2           False  False     False  False     False    False     False
# 3           False  False     False  False     False    False     False
# 4           False  False     False  False     False    False     False
# ...           ...    ...       ...    ...       ...      ...       ...
# 11270       False  False     False  False     False    False      True
# 11271       False  False     False  False     False    False      True
# 11272       False  False     False  False     False    False      True
# 11273       False  False     False  False     False    False      True
# 11274       False  False     False  False     False    False      True
#
#        PaperlessBilling  PaymentMethod  Charges.Monthly  Charges.Total  \
# ...

# %%
datos_telecom.Churn.isnull().sum()
# Out:
# np.int64(0)

# %%
datos_telecom.query("Churn==''")
# Out:
#        customerID Churn                                           customer  \
# 30     0047-ZHDTW        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 75     0120-YZLQA        {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 96     0154-QYHJU        {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 98     0162-RZGMZ        {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 175    0274-VVQOQ        {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# ...           ...   ...                                                ...
# 11166  9840-GSRFX        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 11188  9872-RZQQB        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 11219  9920-GNDMB        {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 11247  9955-RVWSC        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 11255  9966-VYRTZ        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                    phone  \
# ...

# %%
datos_telecom.query("Churn==''").index
# Out:
# Index([   30,    75,    96,    98,   175,   219,   312,   351,   368,   374,
#        ...
#        11066, 11069, 11070, 11151, 11163, 11166, 11188, 11219, 11247, 11255],
#       dtype='int64', length=348)

# %%
datos_telecom.drop(datos_telecom.query("Churn==''").index, inplace=True)

# %%
datos_telecom.Churn.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
datos_telecom = datos_telecom.fillna(0)
datos_telecom.isnull().sum()
# Out:
# customerID          0
# Churn               0
# customer            0
# phone               0
# internet            0
# account             0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# dtype: int64

# %%
datos_telecom.Contract.unique()
# Out:
# array(['One year', 'Month-to-month', 'Two year', 0], dtype=object)

# %%
df_remover = datos_telecom.query('Contract==0').index

# %%
datos_telecom.drop(df_remover, axis=0, inplace=True)

# %%
datos_telecom.Contract.unique()
# Out:
# array(['One year', 'Month-to-month', 'Two year'], dtype=object)

# %%
datos_telecom
# Out:
#        customerID Churn                                           customer  \
# 0      0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1      0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2      0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3      0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4      0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...           ...   ...                                                ...
# 10590  9054-FOWNV    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 10591  9055-MOJJJ    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 10592  9057-MSWCO   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 10593  9057-SIHCH   Yes  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 10594  9058-CBREO   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                                    phone  \
# ...

# %%
datos_telecom.isnull().sum()
# Out:
# customerID          0
# Churn               0
# customer            0
# phone               0
# internet            0
# account             0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# dtype: int64

# %%
df_norm.PaperlessBilling.value_counts()
# Out:
# PaperlessBilling
# Yes    6286
# No     4309
# Name: count, dtype: int64

# %%
datos_telecom.customerID.unique()
# Out:
# array(['0002-ORFBO', '0003-MKNFE', '0004-TLHLJ', ..., '9057-MSWCO',
#        '9057-SIHCH', '9058-CBREO'], dtype=object)

# %%
df_norm['Cuentas_Diarias'] = (df_norm['Charges.Monthly']*12)/365
df_norm
# Out:
#              Contract PaperlessBilling              PaymentMethod  \
# 0            One year              Yes               Mailed check
# 1      Month-to-month               No               Mailed check
# 2      Month-to-month              Yes           Electronic check
# 3      Month-to-month              Yes           Electronic check
# 4      Month-to-month              Yes               Mailed check
# ...               ...              ...                        ...
# 10590  Month-to-month              Yes           Electronic check
# 10591  Month-to-month               No               Mailed check
# 10592  Month-to-month               No           Electronic check
# 10593  Month-to-month              Yes  Bank transfer (automatic)
# 10594  Month-to-month               No           Electronic check
#
#        Charges.Monthly Charges.Total  Cuentas_Diarias
# 0                65.60         593.3         2.156712
# 1                59.90         542.4         1.969315
# ...

# %% [markdown]
# #📊 Carga y análisis

# %%
df_norm
# Out:
#              Contract PaperlessBilling              PaymentMethod  \
# 0            One year              Yes               Mailed check
# 1      Month-to-month               No               Mailed check
# 2      Month-to-month              Yes           Electronic check
# 3      Month-to-month              Yes           Electronic check
# 4      Month-to-month              Yes               Mailed check
# ...               ...              ...                        ...
# 10590  Month-to-month              Yes           Electronic check
# 10591  Month-to-month               No               Mailed check
# 10592  Month-to-month               No           Electronic check
# 10593  Month-to-month              Yes  Bank transfer (automatic)
# 10594  Month-to-month               No           Electronic check
#
#        Charges.Monthly Charges.Total  Cuentas_Diarias
# 0                65.60         593.3         2.156712
# 1                59.90         542.4         1.969315
# ...

# %%
df_norm.describe()
# Out:
#        Charges.Monthly  Cuentas_Diarias
# count     10595.000000     10595.000000
# mean         64.906479         2.133912
# std          29.992551         0.986056
# min          18.250000         0.600000
# 25%          35.800000         1.176986
# 50%          70.500000         2.317808
# 75%          89.850000         2.953973
# max         118.750000         3.904110

# %%
data_grafico = datos_telecom.groupby(['Churn'])['customerID'].count()
data_grafico.plot(kind='barh', figsize=(12,8), color='red')
# Out:
# <Axes: ylabel='Churn'>

# %%
datos_telecom.groupby(['Churn'])['customerID'].count()
# Out:
# Churn
# No     7470
# Yes    2809
# Name: customerID, dtype: int64

# %%
datos_telecom.groupby(['Contract'])['Churn'].count()
# Out:
# Contract
# Month-to-month    5735
# One year          2127
# Two year          2417
# Name: Churn, dtype: int64

# %%
datos_telecom.groupby(['PaymentMethod'])['Churn'].count()
# Out:
# PaymentMethod
# Bank transfer (automatic)    2268
# Credit card (automatic)      2192
# Electronic check             3480
# Mailed check                 2339
# Name: Churn, dtype: int64

# %%
datos_telecom.groupby(['gender'])['Churn'].count()
# Out:
# gender
# Female    5067
# Male      5212
# Name: Churn, dtype: int64

# %%
datos_telecom.groupby(['Charges.Total'])['Churn'].count()
# Out:
# Charges.Total
#           23
# 100.2      1
# 100.25     3
# 100.35     1
# 100.4      1
#           ..
# 997.75     1
# 998.1      1
# 999.45     1
# 999.8      3
# 999.9      1
# Name: Churn, Length: 6122, dtype: int64

# %% [markdown]
# #📄Informe final

# %% [markdown]
# 1. Introducción:
# El presente análisis tiene como objetivo identificar y comprender los factores que influyen en la evasión de clientes (Customer Churn).
# La evasión, o pérdida de clientes, representa un problema significativo para las empresas, ya que implica no solo la reducción de ingresos sino también el incremento de costos al adquirir nuevos clientes.
# Mediante el uso de análisis de datos, se busca detectar patrones asociados a variables como género, tipo de contrato y método de pago, para proponer acciones que reduzcan la tasa de abandono.
#
# 2. Limpieza y Tratamiento de Datos
# Los datos fueron importados desde un archivos JSON y organizados en dos tablas principales:
#
# Tabla general: La cual contiene todos los datos entregado en el archivo JSON
#
# Tabla de Cuentas: Conteniendo información sobre tipo de pagos, cargos diarios y mensuales, la totalidad cobrado, entre otros.
#
# Pasos Realizados
#
# Importación de datos: Uso de pandas para obtener y almacenar la información.
# Desglose de tablas: Mediante el uso de "pd.json_normalize"
# Union de tablas: Utilizando "pd.concat"
# Tratamiento de valores faltantes: Se eliminaron registros incompletos.
# Normalización de categorías: Unificación de nombres y formatos para evitar duplicados no intencionales.
#
# 3. Análisis Exploratorio de Datos
# Se realizó un análisis de tasa de evasión (%) para cada variable categórica:
#
# Género: Cálculo de abandono por hombres y mujeres.
# Tipo de Contrato: Comparación entre planes mensuales y anuales.
# Método de Pago: Evaluación según uso de tarjeta o efectivo.
#
# Principales observaciones gráficas:
#
# Los contratos mensuales presentaron mayor tasa de abandono que los anuales.
# Determinados métodos de pago, como electronic check o mail check, mostraron tasas de evasión más altas.
# No se detectaron diferencias significativas por género.
#
# 4. Conclusiones e Insights
#
# El análisis revela que el tipo de contrato y el método de pago tienen un impacto considerable en la probabilidad de evasión.
#
# Los planes anuales parecen retener mejor a los clientes.
# Métodos de pago automáticos, como tarjetas, se asocian con menor abandono.
#
# Recomendaciones:
#
# Incentivar planes anuales mediante descuentos o beneficios exclusivos.
# Promover el pago automático para reducir la fricción de pago mensual.
# Implementar campañas de fidelización orientadas a clientes con contrato mensual o pago en efectivo.
#
# Este análisis proporciona una base sólida para el diseño de estrategias que apunten a reducir la evasión y mejorar la retención a largo plazo.
